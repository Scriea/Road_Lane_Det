# %%
import os
import sys
import random
import numpy as np
import pandas as pd
import cv2
from google.colab.patches import cv2_imshow

# %%
from skimage.io import imshow, imread, imsave
from skimage.transform import rotate, AffineTransform, warp,rescale, resize, downscale_local_mean
from skimage import color,data
from skimage.exposure import adjust_gamma
from skimage.util import random_noise

# %%
import numpy as np
import pickle
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# Import necessary items from Keras
from keras.models import Sequential
from keras.layers import Activation, Dropout, UpSampling2D
from keras.layers import Conv2DTranspose, Conv2D, MaxPooling2D
#from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras import regularizers

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Activation,AveragePooling2D ,ReLU ,Add,Dense,Reshape,Multiply, Dropout, UpSampling2D,Conv2D,MaxPooling2D,concatenate,add,GlobalAveragePooling2D,GlobalMaxPool2D,Multiply

# %%
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50,MobileNetV2

# %% [markdown]
# #Import Data

# %%
# !gdown --folder https://drive.google.com/drive/folders/1dDjXIevr0f3WKpUzITCTMkYiOXrvUILJ
# Out:
# Retrieving folder list
# Processing file 1Ey4_8fZTE6RsI2zrUaMGYOWLNMVzMIiQ image.npy
# Processing file 17vSqvr2uMUzz-3y8fCkU6RXZEhgz8pKm label.npy
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1Ey4_8fZTE6RsI2zrUaMGYOWLNMVzMIiQ
# To: /content/LaneDetection_Data/image.npy
# 100% 576M/576M [00:02<00:00, 228MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=17vSqvr2uMUzz-3y8fCkU6RXZEhgz8pKm
# To: /content/LaneDetection_Data/label.npy
# 100% 192M/192M [00:00<00:00, 238MB/s]
# Download completed

# %%
train_images =np.load("/content/LaneDetection_Data/image.npy").astype(np.uint8)
labels = np.load("/content/LaneDetection_Data/label.npy").astype(np.uint8)
train_images = np.array(train_images)[0:8000]
labels = np.array(labels)[0:8000]

# %%
shape = train_images[0].shape

# %%
# import skimage
# import matplotlib.pyplot as plt
# img = train_images[1000]

# gimg = skimage.util.random_noise(img/255.0, mode='speckle')*255.0
# cv2_imshow(gimg)

# %% [markdown]
# ##Augmentation

# %%
aug_images = []
aug_labels = []
for i in range(len(train_images)):
  if i%3==0:    ## G + N
    gamma_corrected = adjust_gamma(train_images[i], gamma = 0.8, gain = 1)
    noise_img = 255.0*random_noise(gamma_corrected/255.0, mode = 'speckle')
    aug_images.append(noise_img)
    aug_labels.append(labels[i])
    
  elif i%3 == 1:  ## N + F
    noise_img = 255.0*random_noise(train_images[i]/255.0, mode = 'speckle')
    noise_img = cv2.flip(noise_img, 1)
    aug_images.append(noise_img)
    aug_labels.append(cv2.flip(labels[i],1))

  else:    ## F + G
    gamma_corrected = adjust_gamma(train_images[i], gamma = 0.8, gain = 1)
    flip = cv2.flip(gamma_corrected,1)
    aug_images.append(flip)
    aug_labels.append(cv2.flip(labels[i],1))

aug_images = np.array(aug_images).astype(np.uint8)
aug_labels = np.array(aug_labels).astype(np.uint8)

# %%
train_images = np.concatenate((train_images, aug_images), axis =0)
lables = np.concatenate((labels, aug_labels), axis = 0)

# %%
aug_labels.shape
# Out:
# (8000, 80, 160)

# %%
train_images = np.array(aug_images)
lables = np.array(aug_labels)
labels = labels / 255.0
train_images, labels = shuffle(train_images, labels)
X_train, X_val, y_train, y_val = train_test_split(train_images, labels, test_size=0.3)
batch_size =64
epochs = 100
pool_size = (2, 2)
input_shape = X_train.shape[1:]
y_train=y_train.reshape(y_train.shape[0],80,160,1)
y_val=y_val.reshape(y_val.shape[0],80,160,1)
print(y_val.shape)
# Out:
# (2400, 80, 160, 1)

# %% [markdown]
# #Metrics

# %%
import tensorflow.keras.backend as K

def dsc(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)


def dice_loss(y_true, y_pred):
    return 1.0 - dsc(y_true, y_pred)



def IOU(y_true, y_pred):

    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)

    thresh = 0.5

    y_true = K.cast(K.greater_equal(y_true, thresh), 'float32')
    y_pred = K.cast(K.greater_equal(y_pred, thresh), 'float32')

    union = K.sum(K.maximum(y_true, y_pred)) + K.epsilon()
    intersection = K.sum(K.minimum(y_true, y_pred)) + K.epsilon()

    iou = intersection/union

    return iou

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# #Model

# %%
def deconv(x, kernelsize,fi):
    #fi=x.shape[-1]
    fx = Conv2DTranspose(fi, kernelsize, activation='relu', padding='same')(x)
    fx = BatchNormalization()(fx)
    fx =Conv2DTranspose(fi, kernelsize, padding='same')(fx)
    out = BatchNormalization()(fx)
    return out

# %%
def CBAM (x,r):
    
    ###### Channel Attention ##########
    f=x.shape[-1]
    a_pool = GlobalAveragePooling2D()(x)
    m_pool = GlobalMaxPool2D()(x) 
    Dense_layer1 = Dense (f // r , activation = 'relu') 
    Dense_layer2 = Dense (f, activation = 'relu') 
    avg_out = Dense_layer2 (Dense_layer1(a_pool)) 
    max_out = Dense_layer2 (Dense_layer1( m_pool))
    channel = add([ avg_out,max_out]) 
    channel = Activation('sigmoid') (channel) 
    channel = Reshape ((1,1,f)) (channel)  
    C_out = Multiply()([x,channel])
   
    
                      
    ###### Spatial Attention ########
    av_pooling=AveragePooling2D(pool_size=(1,1))(C_out)
    ma_pooling=MaxPooling2D(pool_size=(1,1))(C_out)
    spatial=concatenate([av_pooling,ma_pooling], axis = 3)
    spatial =Conv2D(1,(7,7),strides=1,padding ='same') (spatial) 
    #spatial=ASPP(x,spatial)
    
    spatial= Activation('sigmoid')(spatial)
      
    S_out = Multiply()([C_out,spatial])
    
    return S_out

# %%
def resblock(x, kernelsize,fi):
    #fi=x.shape[-1]
    fx = Conv2D(fi, kernelsize, activation='relu', padding='same')(x)
    fx = BatchNormalization()(fx)
    fx =Conv2D(fi, kernelsize, padding='same')(fx)
    x=Conv2D(1,1, activation='relu', padding='same')(x)
    out = Add()([x,fx])
    out = ReLU()(out)
    out = BatchNormalization()(out)
    return out

# %%
inputs = keras.layers.Input((80,160,3))

block1=resblock(inputs,3,8)
pool1 = MaxPooling2D(pool_size=(2, 2),name="pool1")(block1)
block2=resblock(pool1,3,16)
pool2 = MaxPooling2D(pool_size=(2, 2),name="pool2")(block2)
block3=resblock(pool2,3,32)
pool3 = MaxPooling2D(pool_size=(2, 2),name="pool3")(block3)
block4=resblock(pool3,3,64)
pool4 = MaxPooling2D(pool_size=(2, 2),name="pool4")(block4)

a1=CBAM (pool1,8)
a2=CBAM (pool2,8)
a2=UpSampling2D(size = (2,2))(a2)
c1=concatenate([a1,a2], axis = 3)
a3=CBAM (pool3,8)
a4=CBAM (pool4,8)

a4=UpSampling2D(size = (2,2))(a4)
c2=concatenate([a3,a4], axis = 3)
c2=UpSampling2D(size = (2,2))(c2)

c1=UpSampling2D(size = (2,2))(c1)
D1=deconv(c1, 3,32)

c2=UpSampling2D(size = (4,4))(c2)
D2=deconv(c2, 3,16)

pool4=UpSampling2D(size = (16,16))(pool4)
D3=deconv(pool4, 3,8)
D=concatenate([D1,D2,D3], axis = 3)


O= Conv2DTranspose(1, 1, activation = 'sigmoid')(D)
model = Model(inputs, O)
datagen = ImageDataGenerator(channel_shift_range=0.2)
datagen.fit(X_train)
opt = keras.optimizers.Adam()
model.compile(optimizer=opt,  loss = "binary_crossentropy", metrics = ['dsc','accuracy', 'IOU','precision_m', 'recall_m', 'f1_m'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 80, 160, 3)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 80, 160, 8)   224         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 80, 160, 8)  32          ['conv2d[0][0]']
#  alization)
#
#  conv2d_2 (Conv2D)              (None, 80, 160, 1)   4           ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 80, 160, 8)   584         ['batch_normalization[0][0]']
#
#  add (Add)                      (None, 80, 160, 8)   0           ['conv2d_2[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  re_lu (ReLU)                   (None, 80, 160, 8)   0           ['add[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 80, 160, 8)  32          ['re_lu[0][0]']
#  rmalization)
#
#  pool1 (MaxPooling2D)           (None, 40, 80, 8)    0           ['batch_normalization_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 40, 80, 16)   1168        ['pool1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 40, 80, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 40, 80, 1)    9           ['pool1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 40, 80, 16)   2320        ['batch_normalization_2[0][0]']
#
#  add_1 (Add)                    (None, 40, 80, 16)   0           ['conv2d_5[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 40, 80, 16)   0           ['add_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 40, 80, 16)  64          ['re_lu_1[0][0]']
#  rmalization)
#
#  pool2 (MaxPooling2D)           (None, 20, 40, 16)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 20, 40, 32)   4640        ['pool2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 20, 40, 32)  128         ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 20, 40, 1)    17          ['pool2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 20, 40, 32)   9248        ['batch_normalization_4[0][0]']
#
#  add_2 (Add)                    (None, 20, 40, 32)   0           ['conv2d_8[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 20, 40, 32)   0           ['add_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 20, 40, 32)  128         ['re_lu_2[0][0]']
#  rmalization)
#
#  pool3 (MaxPooling2D)           (None, 10, 20, 32)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 10, 20, 64)   18496       ['pool3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 10, 20, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  conv2d_11 (Conv2D)             (None, 10, 20, 1)    33          ['pool3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 10, 20, 64)   36928       ['batch_normalization_6[0][0]']
#
#  add_3 (Add)                    (None, 10, 20, 64)   0           ['conv2d_11[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 10, 20, 64)   0           ['add_3[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 10, 20, 64)  256         ['re_lu_3[0][0]']
#  rmalization)
#
#  pool4 (MaxPooling2D)           (None, 5, 10, 64)    0           ['batch_normalization_7[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 64)          0           ['pool4[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_3 (Global  (None, 64)          0           ['pool4[0][0]']
#  MaxPooling2D)
#
#  global_average_pooling2d_1 (Gl  (None, 16)          0           ['pool2[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_1 (Global  (None, 16)          0           ['pool2[0][0]']
#  MaxPooling2D)
#
#  global_average_pooling2d_2 (Gl  (None, 32)          0           ['pool3[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_2 (Global  (None, 32)          0           ['pool3[0][0]']
#  MaxPooling2D)
#
#  dense_6 (Dense)                (None, 8)            520         ['global_average_pooling2d_3[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 8)           0           ['pool1[0][0]']
#  alAveragePooling2D)
#
#  global_max_pooling2d (GlobalMa  (None, 8)           0           ['pool1[0][0]']
#  xPooling2D)
#
#  dense_2 (Dense)                (None, 2)            34          ['global_average_pooling2d_1[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_1[0][0]']
#
#  dense_4 (Dense)                (None, 4)            132         ['global_average_pooling2d_2[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_2[0][0]']
#
#  dense_7 (Dense)                (None, 64)           576         ['dense_6[0][0]',
#                                                                   'dense_6[1][0]']
#
#  dense (Dense)                  (None, 1)            9           ['global_average_pooling2d[0][0]'
#                                                                  , 'global_max_pooling2d[0][0]']
#
#  dense_3 (Dense)                (None, 16)           48          ['dense_2[0][0]',
#                                                                   'dense_2[1][0]']
#
#  dense_5 (Dense)                (None, 32)           160         ['dense_4[0][0]',
#                                                                   'dense_4[1][0]']
#
#  add_7 (Add)                    (None, 64)           0           ['dense_7[0][0]',
#                                                                   'dense_7[1][0]']
#
#  dense_1 (Dense)                (None, 8)            16          ['dense[0][0]',
#                                                                   'dense[1][0]']
#
#  add_5 (Add)                    (None, 16)           0           ['dense_3[0][0]',
#                                                                   'dense_3[1][0]']
#
#  add_6 (Add)                    (None, 32)           0           ['dense_5[0][0]',
#                                                                   'dense_5[1][0]']
#
#  activation_6 (Activation)      (None, 64)           0           ['add_7[0][0]']
#
#  add_4 (Add)                    (None, 8)            0           ['dense_1[0][0]',
#                                                                   'dense_1[1][0]']
#
#  activation_2 (Activation)      (None, 16)           0           ['add_5[0][0]']
#
#  activation_4 (Activation)      (None, 32)           0           ['add_6[0][0]']
#
#  reshape_3 (Reshape)            (None, 1, 1, 64)     0           ['activation_6[0][0]']
#
#  activation (Activation)        (None, 8)            0           ['add_4[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 1, 16)     0           ['activation_2[0][0]']
#
#  reshape_2 (Reshape)            (None, 1, 1, 32)     0           ['activation_4[0][0]']
#
#  multiply_6 (Multiply)          (None, 5, 10, 64)    0           ['pool4[0][0]',
#                                                                   'reshape_3[0][0]']
#
#  reshape (Reshape)              (None, 1, 1, 8)      0           ['activation[0][0]']
#
#  multiply_2 (Multiply)          (None, 20, 40, 16)   0           ['pool2[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  multiply_4 (Multiply)          (None, 10, 20, 32)   0           ['pool3[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 5, 10, 64)   0           ['multiply_6[0][0]']
#  oling2D)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 5, 10, 64)   0           ['multiply_6[0][0]']
#
#  multiply (Multiply)            (None, 40, 80, 8)    0           ['pool1[0][0]',
#                                                                   'reshape[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 20, 40, 16)  0           ['multiply_2[0][0]']
#  oling2D)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 20, 40, 16)  0           ['multiply_2[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 10, 20, 32)  0           ['multiply_4[0][0]']
#  oling2D)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 10, 20, 32)  0           ['multiply_4[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 5, 10, 128)   0           ['average_pooling2d_3[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  average_pooling2d (AveragePool  (None, 40, 80, 8)   0           ['multiply[0][0]']
#  ing2D)
#
#  max_pooling2d (MaxPooling2D)   (None, 40, 80, 8)    0           ['multiply[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 20, 40, 32)   0           ['average_pooling2d_1[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 10, 20, 64)   0           ['average_pooling2d_2[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 5, 10, 1)     6273        ['concatenate_4[0][0]']
#
#  concatenate (Concatenate)      (None, 40, 80, 16)   0           ['average_pooling2d[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 20, 40, 1)    1569        ['concatenate_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 10, 20, 1)    3137        ['concatenate_3[0][0]']
#
#  activation_7 (Activation)      (None, 5, 10, 1)     0           ['conv2d_15[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 40, 80, 1)    785         ['concatenate[0][0]']
#
#  activation_3 (Activation)      (None, 20, 40, 1)    0           ['conv2d_13[0][0]']
#
#  activation_5 (Activation)      (None, 10, 20, 1)    0           ['conv2d_14[0][0]']
#
#  multiply_7 (Multiply)          (None, 5, 10, 64)    0           ['multiply_6[0][0]',
#                                                                   'activation_7[0][0]']
#
#  activation_1 (Activation)      (None, 40, 80, 1)    0           ['conv2d_12[0][0]']
#
#  multiply_3 (Multiply)          (None, 20, 40, 16)   0           ['multiply_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  multiply_5 (Multiply)          (None, 10, 20, 32)   0           ['multiply_4[0][0]',
#                                                                   'activation_5[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 10, 20, 64)  0           ['multiply_7[0][0]']
#
#  multiply_1 (Multiply)          (None, 40, 80, 8)    0           ['multiply[0][0]',
#                                                                   'activation_1[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 40, 80, 16)   0           ['multiply_3[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 10, 20, 96)   0           ['multiply_5[0][0]',
#                                                                   'up_sampling2d_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 40, 80, 24)   0           ['multiply_1[0][0]',
#                                                                   'up_sampling2d[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 20, 40, 96)  0           ['concatenate_5[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 80, 160, 24)  0          ['concatenate_2[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 80, 160, 96)  0          ['up_sampling2d_2[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 80, 160, 64)  0          ['pool4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 80, 160, 32)  6944       ['up_sampling2d_3[0][0]']
#  ose)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 80, 160, 16)  13840      ['up_sampling2d_4[0][0]']
#  spose)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 80, 160, 8)  4616        ['up_sampling2d_5[0][0]']
#  spose)
#
#  batch_normalization_8 (BatchNo  (None, 80, 160, 32)  128        ['conv2d_transpose[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 80, 160, 16)  64         ['conv2d_transpose_2[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 80, 160, 8)  32          ['conv2d_transpose_4[0][0]']
#  ormalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 80, 160, 32)  9248       ['batch_normalization_8[0][0]']
#  spose)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 80, 160, 16)  2320       ['batch_normalization_10[0][0]']
#  spose)
#
#  conv2d_transpose_5 (Conv2DTran  (None, 80, 160, 8)  584         ['batch_normalization_12[0][0]']
#  spose)
#
#  batch_normalization_9 (BatchNo  (None, 80, 160, 32)  128        ['conv2d_transpose_1[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 80, 160, 16)  64         ['conv2d_transpose_3[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 80, 160, 8)  32          ['conv2d_transpose_5[0][0]']
#  ormalization)
#
#  concatenate_6 (Concatenate)    (None, 80, 160, 56)  0           ['batch_normalization_9[0][0]',
#                                                                   'batch_normalization_11[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 80, 160, 1)  57          ['concatenate_6[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 125,947
# Trainable params: 125,243
# Non-trainable params: 704
# __________________________________________________________________________________________________

# %%
model.save('LLDNet.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from tensorflow.keras.models import load_model
# load model
model = load_model('LLDNet.h5',custom_objects={'dice_loss':dice_loss,'IOU':IOU,'dsc':dsc,'precision_m':precision_m, 'recall_m':recall_m, 'f1_m':f1_m})
# summarize model.

# %%
epochs = 100
history=model.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size), steps_per_epoch=len(X_train)/batch_size,
epochs=epochs, verbose=1, validation_data=(X_val, y_val))

model.save('LLDNet_aug1.h5')
# Out:
# Epoch 1/100
# <ipython-input-38-b7be5a4aa97d>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size), steps_per_epoch=len(X_train)/batch_size,
# 87/87 [==============================] - 19s 212ms/step - loss: 0.0928 - dsc: 0.8221 - accuracy: 0.9408 - IOU: 0.7930 - precision_m: 0.8884 - recall_m: 0.8651 - f1_m: 0.8763 - val_loss: 0.0998 - val_dsc: 0.8072 - val_accuracy: 0.9362 - val_IOU: 0.7581 - val_precision_m: 0.8881 - val_recall_m: 0.8236 - val_f1_m: 0.8545
# Epoch 2/100
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0837 - dsc: 0.8396 - accuracy: 0.9434 - IOU: 0.8081 - precision_m: 0.8969 - recall_m: 0.8749 - f1_m: 0.8855 - val_loss: 0.0852 - val_dsc: 0.8460 - val_accuracy: 0.9424 - val_IOU: 0.8059 - val_precision_m: 0.8841 - val_recall_m: 0.8844 - val_f1_m: 0.8842
# Epoch 3/100
# 87/87 [==============================] - 19s 219ms/step - loss: 0.0775 - dsc: 0.8522 - accuracy: 0.9453 - IOU: 0.8193 - precision_m: 0.9027 - recall_m: 0.8826 - f1_m: 0.8924 - val_loss: 0.0836 - val_dsc: 0.8405 - val_accuracy: 0.9425 - val_IOU: 0.7959 - val_precision_m: 0.9282 - val_recall_m: 0.8353 - val_f1_m: 0.8792
# Epoch 4/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0739 - dsc: 0.8589 - accuracy: 0.9463 - IOU: 0.8258 - precision_m: 0.9071 - recall_m: 0.8860 - f1_m: 0.8963 - val_loss: 0.0747 - val_dsc: 0.8609 - val_accuracy: 0.9453 - val_IOU: 0.8240 - val_precision_m: 0.8926 - val_recall_m: 0.8974 - val_f1_m: 0.8949
# Epoch 5/100
# 87/87 [==============================] - 19s 215ms/step - loss: 0.0691 - dsc: 0.8686 - accuracy: 0.9480 - IOU: 0.8365 - precision_m: 0.9118 - recall_m: 0.8938 - f1_m: 0.9026 - val_loss: 0.0722 - val_dsc: 0.8694 - val_accuracy: 0.9464 - val_IOU: 0.8286 - val_precision_m: 0.9105 - val_recall_m: 0.8872 - val_f1_m: 0.8987
# Epoch 6/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0656 - dsc: 0.8750 - accuracy: 0.9492 - IOU: 0.8443 - precision_m: 0.9157 - recall_m: 0.8990 - f1_m: 0.9071 - val_loss: 0.0749 - val_dsc: 0.8699 - val_accuracy: 0.9461 - val_IOU: 0.8284 - val_precision_m: 0.8923 - val_recall_m: 0.9038 - val_f1_m: 0.8979
# Epoch 7/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0642 - dsc: 0.8786 - accuracy: 0.9496 - IOU: 0.8472 - precision_m: 0.9174 - recall_m: 0.9007 - f1_m: 0.9089 - val_loss: 0.0717 - val_dsc: 0.8720 - val_accuracy: 0.9468 - val_IOU: 0.8320 - val_precision_m: 0.9010 - val_recall_m: 0.8999 - val_f1_m: 0.9004
# Epoch 8/100
# 87/87 [==============================] - 19s 217ms/step - loss: 0.0609 - dsc: 0.8843 - accuracy: 0.9508 - IOU: 0.8546 - precision_m: 0.9210 - recall_m: 0.9057 - f1_m: 0.9132 - val_loss: 0.0675 - val_dsc: 0.8841 - val_accuracy: 0.9488 - val_IOU: 0.8459 - val_precision_m: 0.9005 - val_recall_m: 0.9169 - val_f1_m: 0.9086
# Epoch 9/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0588 - dsc: 0.8887 - accuracy: 0.9516 - IOU: 0.8598 - precision_m: 0.9240 - recall_m: 0.9087 - f1_m: 0.9162 - val_loss: 0.0708 - val_dsc: 0.8810 - val_accuracy: 0.9475 - val_IOU: 0.8392 - val_precision_m: 0.8914 - val_recall_m: 0.9190 - val_f1_m: 0.9049
# Epoch 10/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0571 - dsc: 0.8918 - accuracy: 0.9521 - IOU: 0.8633 - precision_m: 0.9258 - recall_m: 0.9110 - f1_m: 0.9182 - val_loss: 0.0642 - val_dsc: 0.8886 - val_accuracy: 0.9495 - val_IOU: 0.8504 - val_precision_m: 0.9078 - val_recall_m: 0.9146 - val_f1_m: 0.9111
# Epoch 11/100
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0555 - dsc: 0.8949 - accuracy: 0.9526 - IOU: 0.8670 - precision_m: 0.9276 - recall_m: 0.9135 - f1_m: 0.9203 - val_loss: 0.0641 - val_dsc: 0.8896 - val_accuracy: 0.9493 - val_IOU: 0.8528 - val_precision_m: 0.8963 - val_recall_m: 0.9291 - val_f1_m: 0.9124
# Epoch 12/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0531 - dsc: 0.8994 - accuracy: 0.9536 - IOU: 0.8732 - precision_m: 0.9305 - recall_m: 0.9176 - f1_m: 0.9239 - val_loss: 0.0607 - val_dsc: 0.8912 - val_accuracy: 0.9508 - val_IOU: 0.8554 - val_precision_m: 0.9220 - val_recall_m: 0.9067 - val_f1_m: 0.9143
# Epoch 13/100
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0525 - dsc: 0.9012 - accuracy: 0.9537 - IOU: 0.8742 - precision_m: 0.9313 - recall_m: 0.9182 - f1_m: 0.9245 - val_loss: 0.0615 - val_dsc: 0.8898 - val_accuracy: 0.9504 - val_IOU: 0.8523 - val_precision_m: 0.9245 - val_recall_m: 0.9008 - val_f1_m: 0.9125
# Epoch 14/100
# 87/87 [==============================] - 19s 217ms/step - loss: 0.0508 - dsc: 0.9040 - accuracy: 0.9544 - IOU: 0.8786 - precision_m: 0.9334 - recall_m: 0.9210 - f1_m: 0.9270 - val_loss: 0.0596 - val_dsc: 0.8959 - val_accuracy: 0.9513 - val_IOU: 0.8575 - val_precision_m: 0.9342 - val_recall_m: 0.8984 - val_f1_m: 0.9159
# Epoch 15/100
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0499 - dsc: 0.9060 - accuracy: 0.9547 - IOU: 0.8807 - precision_m: 0.9344 - recall_m: 0.9223 - f1_m: 0.9282 - val_loss: 0.0628 - val_dsc: 0.8897 - val_accuracy: 0.9499 - val_IOU: 0.8492 - val_precision_m: 0.9335 - val_recall_m: 0.8897 - val_f1_m: 0.9110
# Epoch 16/100
# 87/87 [==============================] - 19s 220ms/step - loss: 0.0487 - dsc: 0.9083 - accuracy: 0.9551 - IOU: 0.8838 - precision_m: 0.9359 - recall_m: 0.9242 - f1_m: 0.9299 - val_loss: 0.0605 - val_dsc: 0.9006 - val_accuracy: 0.9511 - val_IOU: 0.8627 - val_precision_m: 0.9072 - val_recall_m: 0.9307 - val_f1_m: 0.9188
# Epoch 17/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0474 - dsc: 0.9105 - accuracy: 0.9556 - IOU: 0.8871 - precision_m: 0.9377 - recall_m: 0.9260 - f1_m: 0.9318 - val_loss: 0.0651 - val_dsc: 0.9008 - val_accuracy: 0.9502 - val_IOU: 0.8609 - val_precision_m: 0.8903 - val_recall_m: 0.9472 - val_f1_m: 0.9178
# Epoch 18/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0468 - dsc: 0.9121 - accuracy: 0.9557 - IOU: 0.8882 - precision_m: 0.9379 - recall_m: 0.9272 - f1_m: 0.9324 - val_loss: 0.0576 - val_dsc: 0.9014 - val_accuracy: 0.9519 - val_IOU: 0.8655 - val_precision_m: 0.9250 - val_recall_m: 0.9157 - val_f1_m: 0.9203
# Epoch 19/100
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0460 - dsc: 0.9136 - accuracy: 0.9560 - IOU: 0.8902 - precision_m: 0.9392 - recall_m: 0.9282 - f1_m: 0.9336 - val_loss: 0.0572 - val_dsc: 0.9053 - val_accuracy: 0.9521 - val_IOU: 0.8688 - val_precision_m: 0.9185 - val_recall_m: 0.9260 - val_f1_m: 0.9222
# Epoch 20/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0448 - dsc: 0.9155 - accuracy: 0.9565 - IOU: 0.8934 - precision_m: 0.9403 - recall_m: 0.9305 - f1_m: 0.9353 - val_loss: 0.0584 - val_dsc: 0.9049 - val_accuracy: 0.9522 - val_IOU: 0.8663 - val_precision_m: 0.9240 - val_recall_m: 0.9181 - val_f1_m: 0.9210
# Epoch 21/100
# 87/87 [==============================] - 19s 220ms/step - loss: 0.0442 - dsc: 0.9168 - accuracy: 0.9567 - IOU: 0.8947 - precision_m: 0.9412 - recall_m: 0.9310 - f1_m: 0.9360 - val_loss: 0.0583 - val_dsc: 0.9047 - val_accuracy: 0.9522 - val_IOU: 0.8669 - val_precision_m: 0.9184 - val_recall_m: 0.9238 - val_f1_m: 0.9211
# Epoch 22/100
# 87/87 [==============================] - 19s 220ms/step - loss: 0.0431 - dsc: 0.9188 - accuracy: 0.9570 - IOU: 0.8975 - precision_m: 0.9423 - recall_m: 0.9329 - f1_m: 0.9375 - val_loss: 0.0567 - val_dsc: 0.9046 - val_accuracy: 0.9525 - val_IOU: 0.8696 - val_precision_m: 0.9188 - val_recall_m: 0.9261 - val_f1_m: 0.9224
# Epoch 23/100
# 87/87 [==============================] - 19s 217ms/step - loss: 0.0436 - dsc: 0.9181 - accuracy: 0.9568 - IOU: 0.8961 - precision_m: 0.9420 - recall_m: 0.9319 - f1_m: 0.9368 - val_loss: 0.0549 - val_dsc: 0.9076 - val_accuracy: 0.9531 - val_IOU: 0.8729 - val_precision_m: 0.9297 - val_recall_m: 0.9193 - val_f1_m: 0.9245
# Epoch 24/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0424 - dsc: 0.9204 - accuracy: 0.9573 - IOU: 0.8992 - precision_m: 0.9434 - recall_m: 0.9340 - f1_m: 0.9386 - val_loss: 0.0555 - val_dsc: 0.9090 - val_accuracy: 0.9531 - val_IOU: 0.8731 - val_precision_m: 0.9285 - val_recall_m: 0.9214 - val_f1_m: 0.9249
# Epoch 25/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0418 - dsc: 0.9215 - accuracy: 0.9575 - IOU: 0.9007 - precision_m: 0.9439 - recall_m: 0.9350 - f1_m: 0.9393 - val_loss: 0.0609 - val_dsc: 0.9065 - val_accuracy: 0.9513 - val_IOU: 0.8665 - val_precision_m: 0.9004 - val_recall_m: 0.9431 - val_f1_m: 0.9212
# Epoch 26/100
# 87/87 [==============================] - 19s 217ms/step - loss: 0.0417 - dsc: 0.9218 - accuracy: 0.9575 - IOU: 0.9009 - precision_m: 0.9441 - recall_m: 0.9350 - f1_m: 0.9395 - val_loss: 0.0543 - val_dsc: 0.9092 - val_accuracy: 0.9535 - val_IOU: 0.8736 - val_precision_m: 0.9349 - val_recall_m: 0.9153 - val_f1_m: 0.9250
# Epoch 27/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0403 - dsc: 0.9239 - accuracy: 0.9580 - IOU: 0.9043 - precision_m: 0.9456 - recall_m: 0.9370 - f1_m: 0.9412 - val_loss: 0.0532 - val_dsc: 0.9100 - val_accuracy: 0.9536 - val_IOU: 0.8751 - val_precision_m: 0.9388 - val_recall_m: 0.9132 - val_f1_m: 0.9258
# Epoch 28/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0404 - dsc: 0.9244 - accuracy: 0.9579 - IOU: 0.9042 - precision_m: 0.9454 - recall_m: 0.9373 - f1_m: 0.9413 - val_loss: 0.0578 - val_dsc: 0.9120 - val_accuracy: 0.9528 - val_IOU: 0.8730 - val_precision_m: 0.9203 - val_recall_m: 0.9303 - val_f1_m: 0.9253
# Epoch 29/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0392 - dsc: 0.9261 - accuracy: 0.9583 - IOU: 0.9071 - precision_m: 0.9473 - recall_m: 0.9384 - f1_m: 0.9428 - val_loss: 0.0552 - val_dsc: 0.9111 - val_accuracy: 0.9534 - val_IOU: 0.8749 - val_precision_m: 0.9275 - val_recall_m: 0.9245 - val_f1_m: 0.9259
# Epoch 30/100
# 87/87 [==============================] - 19s 217ms/step - loss: 0.0390 - dsc: 0.9268 - accuracy: 0.9584 - IOU: 0.9076 - precision_m: 0.9475 - recall_m: 0.9390 - f1_m: 0.9431 - val_loss: 0.0549 - val_dsc: 0.9124 - val_accuracy: 0.9535 - val_IOU: 0.8740 - val_precision_m: 0.9441 - val_recall_m: 0.9084 - val_f1_m: 0.9259
# Epoch 31/100
# 87/87 [==============================] - 19s 217ms/step - loss: 0.0387 - dsc: 0.9272 - accuracy: 0.9585 - IOU: 0.9083 - precision_m: 0.9476 - recall_m: 0.9396 - f1_m: 0.9435 - val_loss: 0.0576 - val_dsc: 0.9125 - val_accuracy: 0.9527 - val_IOU: 0.8755 - val_precision_m: 0.9087 - val_recall_m: 0.9447 - val_f1_m: 0.9263
# Epoch 32/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0384 - dsc: 0.9278 - accuracy: 0.9586 - IOU: 0.9091 - precision_m: 0.9479 - recall_m: 0.9401 - f1_m: 0.9440 - val_loss: 0.0596 - val_dsc: 0.9063 - val_accuracy: 0.9522 - val_IOU: 0.8645 - val_precision_m: 0.9354 - val_recall_m: 0.9060 - val_f1_m: 0.9204
# Epoch 33/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0379 - dsc: 0.9287 - accuracy: 0.9588 - IOU: 0.9103 - precision_m: 0.9486 - recall_m: 0.9408 - f1_m: 0.9446 - val_loss: 0.0564 - val_dsc: 0.9091 - val_accuracy: 0.9528 - val_IOU: 0.8709 - val_precision_m: 0.9333 - val_recall_m: 0.9143 - val_f1_m: 0.9236
# Epoch 34/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0389 - dsc: 0.9274 - accuracy: 0.9584 - IOU: 0.9078 - precision_m: 0.9473 - recall_m: 0.9394 - f1_m: 0.9433 - val_loss: 0.0585 - val_dsc: 0.9082 - val_accuracy: 0.9524 - val_IOU: 0.8682 - val_precision_m: 0.9250 - val_recall_m: 0.9195 - val_f1_m: 0.9222
# Epoch 35/100
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0374 - dsc: 0.9294 - accuracy: 0.9589 - IOU: 0.9115 - precision_m: 0.9490 - recall_m: 0.9417 - f1_m: 0.9452 - val_loss: 0.0542 - val_dsc: 0.9142 - val_accuracy: 0.9541 - val_IOU: 0.8773 - val_precision_m: 0.9392 - val_recall_m: 0.9163 - val_f1_m: 0.9276
# Epoch 36/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0357 - dsc: 0.9325 - accuracy: 0.9595 - IOU: 0.9161 - precision_m: 0.9512 - recall_m: 0.9441 - f1_m: 0.9476 - val_loss: 0.0552 - val_dsc: 0.9161 - val_accuracy: 0.9536 - val_IOU: 0.8789 - val_precision_m: 0.9224 - val_recall_m: 0.9347 - val_f1_m: 0.9285
# Epoch 37/100
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0367 - dsc: 0.9311 - accuracy: 0.9591 - IOU: 0.9129 - precision_m: 0.9496 - recall_m: 0.9428 - f1_m: 0.9461 - val_loss: 0.0557 - val_dsc: 0.9133 - val_accuracy: 0.9535 - val_IOU: 0.8739 - val_precision_m: 0.9453 - val_recall_m: 0.9074 - val_f1_m: 0.9260
# Epoch 38/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0358 - dsc: 0.9324 - accuracy: 0.9594 - IOU: 0.9156 - precision_m: 0.9512 - recall_m: 0.9439 - f1_m: 0.9474 - val_loss: 0.0522 - val_dsc: 0.9180 - val_accuracy: 0.9546 - val_IOU: 0.8821 - val_precision_m: 0.9399 - val_recall_m: 0.9208 - val_f1_m: 0.9302
# Epoch 39/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0352 - dsc: 0.9337 - accuracy: 0.9596 - IOU: 0.9172 - precision_m: 0.9517 - recall_m: 0.9450 - f1_m: 0.9483 - val_loss: 0.0536 - val_dsc: 0.9173 - val_accuracy: 0.9541 - val_IOU: 0.8809 - val_precision_m: 0.9271 - val_recall_m: 0.9318 - val_f1_m: 0.9294
# Epoch 40/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0352 - dsc: 0.9339 - accuracy: 0.9596 - IOU: 0.9172 - precision_m: 0.9516 - recall_m: 0.9451 - f1_m: 0.9483 - val_loss: 0.0588 - val_dsc: 0.9144 - val_accuracy: 0.9529 - val_IOU: 0.8743 - val_precision_m: 0.9138 - val_recall_m: 0.9384 - val_f1_m: 0.9259
# Epoch 41/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0352 - dsc: 0.9339 - accuracy: 0.9596 - IOU: 0.9171 - precision_m: 0.9515 - recall_m: 0.9451 - f1_m: 0.9483 - val_loss: 0.0542 - val_dsc: 0.9175 - val_accuracy: 0.9540 - val_IOU: 0.8801 - val_precision_m: 0.9351 - val_recall_m: 0.9236 - val_f1_m: 0.9292
# Epoch 42/100
# 87/87 [==============================] - 19s 217ms/step - loss: 0.0347 - dsc: 0.9346 - accuracy: 0.9598 - IOU: 0.9186 - precision_m: 0.9524 - recall_m: 0.9457 - f1_m: 0.9490 - val_loss: 0.0522 - val_dsc: 0.9183 - val_accuracy: 0.9546 - val_IOU: 0.8827 - val_precision_m: 0.9403 - val_recall_m: 0.9212 - val_f1_m: 0.9306
# Epoch 43/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0345 - dsc: 0.9353 - accuracy: 0.9599 - IOU: 0.9190 - precision_m: 0.9526 - recall_m: 0.9461 - f1_m: 0.9493 - val_loss: 0.0527 - val_dsc: 0.9172 - val_accuracy: 0.9544 - val_IOU: 0.8808 - val_precision_m: 0.9438 - val_recall_m: 0.9156 - val_f1_m: 0.9295
# Epoch 44/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0339 - dsc: 0.9360 - accuracy: 0.9600 - IOU: 0.9204 - precision_m: 0.9530 - recall_m: 0.9471 - f1_m: 0.9500 - val_loss: 0.0532 - val_dsc: 0.9194 - val_accuracy: 0.9545 - val_IOU: 0.8825 - val_precision_m: 0.9382 - val_recall_m: 0.9233 - val_f1_m: 0.9307
# Epoch 45/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0338 - dsc: 0.9365 - accuracy: 0.9601 - IOU: 0.9207 - precision_m: 0.9533 - recall_m: 0.9471 - f1_m: 0.9502 - val_loss: 0.0568 - val_dsc: 0.9188 - val_accuracy: 0.9534 - val_IOU: 0.8802 - val_precision_m: 0.9135 - val_recall_m: 0.9458 - val_f1_m: 0.9293
# Epoch 46/100
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0338 - dsc: 0.9365 - accuracy: 0.9601 - IOU: 0.9206 - precision_m: 0.9534 - recall_m: 0.9470 - f1_m: 0.9501 - val_loss: 0.0559 - val_dsc: 0.9155 - val_accuracy: 0.9536 - val_IOU: 0.8753 - val_precision_m: 0.9489 - val_recall_m: 0.9059 - val_f1_m: 0.9268
# Epoch 47/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0328 - dsc: 0.9378 - accuracy: 0.9604 - IOU: 0.9233 - precision_m: 0.9541 - recall_m: 0.9488 - f1_m: 0.9514 - val_loss: 0.0548 - val_dsc: 0.9175 - val_accuracy: 0.9542 - val_IOU: 0.8791 - val_precision_m: 0.9405 - val_recall_m: 0.9174 - val_f1_m: 0.9288
# Epoch 48/100
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0336 - dsc: 0.9371 - accuracy: 0.9601 - IOU: 0.9211 - precision_m: 0.9537 - recall_m: 0.9473 - f1_m: 0.9504 - val_loss: 0.0549 - val_dsc: 0.9189 - val_accuracy: 0.9540 - val_IOU: 0.8816 - val_precision_m: 0.9244 - val_recall_m: 0.9359 - val_f1_m: 0.9301
# Epoch 49/100
# 87/87 [==============================] - 19s 218ms/step - loss: 0.0329 - dsc: 0.9379 - accuracy: 0.9603 - IOU: 0.9229 - precision_m: 0.9543 - recall_m: 0.9484 - f1_m: 0.9513 - val_loss: 0.0531 - val_dsc: 0.9209 - val_accuracy: 0.9546 - val_IOU: 0.8845 - val_precision_m: 0.9336 - val_recall_m: 0.9301 - val_f1_m: 0.9318
# Epoch 50/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0326 - dsc: 0.9387 - accuracy: 0.9604 - IOU: 0.9237 - precision_m: 0.9547 - recall_m: 0.9490 - f1_m: 0.9518 - val_loss: 0.0554 - val_dsc: 0.9153 - val_accuracy: 0.9538 - val_IOU: 0.8752 - val_precision_m: 0.9513 - val_recall_m: 0.9038 - val_f1_m: 0.9269
# Epoch 51/100
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0330 - dsc: 0.9380 - accuracy: 0.9603 - IOU: 0.9227 - precision_m: 0.9542 - recall_m: 0.9484 - f1_m: 0.9512 - val_loss: 0.0563 - val_dsc: 0.9189 - val_accuracy: 0.9535 - val_IOU: 0.8808 - val_precision_m: 0.9116 - val_recall_m: 0.9480 - val_f1_m: 0.9294
# Epoch 52/100
# 87/87 [==============================] - 20s 223ms/step - loss: 0.0330 - dsc: 0.9382 - accuracy: 0.9603 - IOU: 0.9226 - precision_m: 0.9542 - recall_m: 0.9486 - f1_m: 0.9513 - val_loss: 0.0550 - val_dsc: 0.9199 - val_accuracy: 0.9540 - val_IOU: 0.8825 - val_precision_m: 0.9212 - val_recall_m: 0.9402 - val_f1_m: 0.9306
# Epoch 53/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0323 - dsc: 0.9391 - accuracy: 0.9605 - IOU: 0.9245 - precision_m: 0.9549 - recall_m: 0.9495 - f1_m: 0.9521 - val_loss: 0.0523 - val_dsc: 0.9224 - val_accuracy: 0.9548 - val_IOU: 0.8870 - val_precision_m: 0.9298 - val_recall_m: 0.9363 - val_f1_m: 0.9330
# Epoch 54/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0331 - dsc: 0.9382 - accuracy: 0.9603 - IOU: 0.9224 - precision_m: 0.9544 - recall_m: 0.9481 - f1_m: 0.9511 - val_loss: 0.0573 - val_dsc: 0.9197 - val_accuracy: 0.9536 - val_IOU: 0.8804 - val_precision_m: 0.9172 - val_recall_m: 0.9426 - val_f1_m: 0.9297
# Epoch 55/100
# 87/87 [==============================] - 19s 218ms/step - loss: 0.0324 - dsc: 0.9388 - accuracy: 0.9605 - IOU: 0.9243 - precision_m: 0.9543 - recall_m: 0.9497 - f1_m: 0.9520 - val_loss: 0.0560 - val_dsc: 0.9187 - val_accuracy: 0.9539 - val_IOU: 0.8795 - val_precision_m: 0.9347 - val_recall_m: 0.9238 - val_f1_m: 0.9292
# Epoch 56/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0322 - dsc: 0.9395 - accuracy: 0.9605 - IOU: 0.9247 - precision_m: 0.9553 - recall_m: 0.9496 - f1_m: 0.9523 - val_loss: 0.0534 - val_dsc: 0.9224 - val_accuracy: 0.9548 - val_IOU: 0.8854 - val_precision_m: 0.9364 - val_recall_m: 0.9285 - val_f1_m: 0.9324
# Epoch 57/100
# 87/87 [==============================] - 19s 223ms/step - loss: 0.0313 - dsc: 0.9408 - accuracy: 0.9608 - IOU: 0.9271 - precision_m: 0.9562 - recall_m: 0.9508 - f1_m: 0.9535 - val_loss: 0.0575 - val_dsc: 0.9189 - val_accuracy: 0.9538 - val_IOU: 0.8792 - val_precision_m: 0.9288 - val_recall_m: 0.9293 - val_f1_m: 0.9290
# Epoch 58/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0316 - dsc: 0.9406 - accuracy: 0.9607 - IOU: 0.9263 - precision_m: 0.9559 - recall_m: 0.9506 - f1_m: 0.9532 - val_loss: 0.0565 - val_dsc: 0.9193 - val_accuracy: 0.9539 - val_IOU: 0.8799 - val_precision_m: 0.9328 - val_recall_m: 0.9259 - val_f1_m: 0.9293
# Epoch 59/100
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0312 - dsc: 0.9411 - accuracy: 0.9608 - IOU: 0.9273 - precision_m: 0.9561 - recall_m: 0.9512 - f1_m: 0.9536 - val_loss: 0.0588 - val_dsc: 0.9145 - val_accuracy: 0.9533 - val_IOU: 0.8706 - val_precision_m: 0.9601 - val_recall_m: 0.8919 - val_f1_m: 0.9247
# Epoch 60/100
# 87/87 [==============================] - 19s 217ms/step - loss: 0.0316 - dsc: 0.9406 - accuracy: 0.9607 - IOU: 0.9261 - precision_m: 0.9559 - recall_m: 0.9505 - f1_m: 0.9531 - val_loss: 0.0541 - val_dsc: 0.9215 - val_accuracy: 0.9544 - val_IOU: 0.8836 - val_precision_m: 0.9347 - val_recall_m: 0.9282 - val_f1_m: 0.9314
# Epoch 61/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0315 - dsc: 0.9407 - accuracy: 0.9607 - IOU: 0.9265 - precision_m: 0.9558 - recall_m: 0.9507 - f1_m: 0.9532 - val_loss: 0.0524 - val_dsc: 0.9224 - val_accuracy: 0.9549 - val_IOU: 0.8871 - val_precision_m: 0.9317 - val_recall_m: 0.9345 - val_f1_m: 0.9331
# Epoch 62/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0305 - dsc: 0.9425 - accuracy: 0.9611 - IOU: 0.9293 - precision_m: 0.9572 - recall_m: 0.9522 - f1_m: 0.9546 - val_loss: 0.0529 - val_dsc: 0.9247 - val_accuracy: 0.9550 - val_IOU: 0.8883 - val_precision_m: 0.9298 - val_recall_m: 0.9382 - val_f1_m: 0.9339
# Epoch 63/100
# 87/87 [==============================] - 19s 217ms/step - loss: 0.0306 - dsc: 0.9424 - accuracy: 0.9611 - IOU: 0.9290 - precision_m: 0.9569 - recall_m: 0.9523 - f1_m: 0.9545 - val_loss: 0.0538 - val_dsc: 0.9243 - val_accuracy: 0.9547 - val_IOU: 0.8872 - val_precision_m: 0.9284 - val_recall_m: 0.9385 - val_f1_m: 0.9334
# Epoch 64/100
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0305 - dsc: 0.9425 - accuracy: 0.9611 - IOU: 0.9291 - precision_m: 0.9571 - recall_m: 0.9522 - f1_m: 0.9546 - val_loss: 0.0526 - val_dsc: 0.9234 - val_accuracy: 0.9551 - val_IOU: 0.8866 - val_precision_m: 0.9411 - val_recall_m: 0.9253 - val_f1_m: 0.9331
# Epoch 65/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0310 - dsc: 0.9420 - accuracy: 0.9609 - IOU: 0.9281 - precision_m: 0.9565 - recall_m: 0.9518 - f1_m: 0.9541 - val_loss: 0.0550 - val_dsc: 0.9204 - val_accuracy: 0.9545 - val_IOU: 0.8811 - val_precision_m: 0.9495 - val_recall_m: 0.9118 - val_f1_m: 0.9302
# Epoch 66/100
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0309 - dsc: 0.9420 - accuracy: 0.9609 - IOU: 0.9280 - precision_m: 0.9568 - recall_m: 0.9513 - f1_m: 0.9540 - val_loss: 0.0545 - val_dsc: 0.9219 - val_accuracy: 0.9545 - val_IOU: 0.8847 - val_precision_m: 0.9289 - val_recall_m: 0.9347 - val_f1_m: 0.9318
# Epoch 67/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0300 - dsc: 0.9433 - accuracy: 0.9612 - IOU: 0.9305 - precision_m: 0.9575 - recall_m: 0.9531 - f1_m: 0.9552 - val_loss: 0.0534 - val_dsc: 0.9241 - val_accuracy: 0.9548 - val_IOU: 0.8880 - val_precision_m: 0.9273 - val_recall_m: 0.9404 - val_f1_m: 0.9337
# Epoch 68/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0303 - dsc: 0.9430 - accuracy: 0.9611 - IOU: 0.9297 - precision_m: 0.9572 - recall_m: 0.9528 - f1_m: 0.9549 - val_loss: 0.0551 - val_dsc: 0.9236 - val_accuracy: 0.9545 - val_IOU: 0.8856 - val_precision_m: 0.9275 - val_recall_m: 0.9380 - val_f1_m: 0.9327
# Epoch 69/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0302 - dsc: 0.9433 - accuracy: 0.9611 - IOU: 0.9299 - precision_m: 0.9576 - recall_m: 0.9527 - f1_m: 0.9551 - val_loss: 0.0567 - val_dsc: 0.9173 - val_accuracy: 0.9540 - val_IOU: 0.8756 - val_precision_m: 0.9554 - val_recall_m: 0.9009 - val_f1_m: 0.9273
# Epoch 70/100
# 87/87 [==============================] - 19s 218ms/step - loss: 0.0310 - dsc: 0.9420 - accuracy: 0.9609 - IOU: 0.9279 - precision_m: 0.9567 - recall_m: 0.9516 - f1_m: 0.9540 - val_loss: 0.0558 - val_dsc: 0.9203 - val_accuracy: 0.9545 - val_IOU: 0.8808 - val_precision_m: 0.9468 - val_recall_m: 0.9140 - val_f1_m: 0.9301
# Epoch 71/100
# 87/87 [==============================] - 19s 218ms/step - loss: 0.0299 - dsc: 0.9434 - accuracy: 0.9612 - IOU: 0.9308 - precision_m: 0.9576 - recall_m: 0.9533 - f1_m: 0.9554 - val_loss: 0.0520 - val_dsc: 0.9245 - val_accuracy: 0.9552 - val_IOU: 0.8884 - val_precision_m: 0.9416 - val_recall_m: 0.9268 - val_f1_m: 0.9341
# Epoch 72/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0293 - dsc: 0.9447 - accuracy: 0.9614 - IOU: 0.9324 - precision_m: 0.9583 - recall_m: 0.9544 - f1_m: 0.9563 - val_loss: 0.0547 - val_dsc: 0.9215 - val_accuracy: 0.9547 - val_IOU: 0.8820 - val_precision_m: 0.9535 - val_recall_m: 0.9094 - val_f1_m: 0.9309
# Epoch 73/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0301 - dsc: 0.9436 - accuracy: 0.9612 - IOU: 0.9302 - precision_m: 0.9577 - recall_m: 0.9529 - f1_m: 0.9552 - val_loss: 0.0576 - val_dsc: 0.9197 - val_accuracy: 0.9538 - val_IOU: 0.8791 - val_precision_m: 0.9392 - val_recall_m: 0.9194 - val_f1_m: 0.9292
# Epoch 74/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0298 - dsc: 0.9440 - accuracy: 0.9613 - IOU: 0.9311 - precision_m: 0.9580 - recall_m: 0.9533 - f1_m: 0.9556 - val_loss: 0.0529 - val_dsc: 0.9259 - val_accuracy: 0.9550 - val_IOU: 0.8898 - val_precision_m: 0.9283 - val_recall_m: 0.9415 - val_f1_m: 0.9349
# Epoch 75/100
# 87/87 [==============================] - 19s 218ms/step - loss: 0.0293 - dsc: 0.9448 - accuracy: 0.9614 - IOU: 0.9325 - precision_m: 0.9586 - recall_m: 0.9543 - f1_m: 0.9564 - val_loss: 0.0527 - val_dsc: 0.9242 - val_accuracy: 0.9549 - val_IOU: 0.8880 - val_precision_m: 0.9295 - val_recall_m: 0.9382 - val_f1_m: 0.9338
# Epoch 76/100
# 87/87 [==============================] - 19s 218ms/step - loss: 0.0289 - dsc: 0.9455 - accuracy: 0.9616 - IOU: 0.9335 - precision_m: 0.9591 - recall_m: 0.9547 - f1_m: 0.9569 - val_loss: 0.0532 - val_dsc: 0.9263 - val_accuracy: 0.9553 - val_IOU: 0.8899 - val_precision_m: 0.9345 - val_recall_m: 0.9357 - val_f1_m: 0.9351
# Epoch 77/100
# 87/87 [==============================] - 19s 222ms/step - loss: 0.0287 - dsc: 0.9458 - accuracy: 0.9616 - IOU: 0.9337 - precision_m: 0.9594 - recall_m: 0.9548 - f1_m: 0.9570 - val_loss: 0.0551 - val_dsc: 0.9233 - val_accuracy: 0.9545 - val_IOU: 0.8857 - val_precision_m: 0.9265 - val_recall_m: 0.9390 - val_f1_m: 0.9327
# Epoch 78/100
# 87/87 [==============================] - 19s 223ms/step - loss: 0.0290 - dsc: 0.9455 - accuracy: 0.9615 - IOU: 0.9332 - precision_m: 0.9587 - recall_m: 0.9549 - f1_m: 0.9567 - val_loss: 0.0532 - val_dsc: 0.9254 - val_accuracy: 0.9551 - val_IOU: 0.8886 - val_precision_m: 0.9306 - val_recall_m: 0.9381 - val_f1_m: 0.9343
# Epoch 79/100
# 87/87 [==============================] - 19s 217ms/step - loss: 0.0287 - dsc: 0.9459 - accuracy: 0.9616 - IOU: 0.9339 - precision_m: 0.9593 - recall_m: 0.9549 - f1_m: 0.9570 - val_loss: 0.0530 - val_dsc: 0.9267 - val_accuracy: 0.9550 - val_IOU: 0.8906 - val_precision_m: 0.9272 - val_recall_m: 0.9439 - val_f1_m: 0.9355
# Epoch 80/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0288 - dsc: 0.9458 - accuracy: 0.9616 - IOU: 0.9337 - precision_m: 0.9592 - recall_m: 0.9550 - f1_m: 0.9570 - val_loss: 0.0534 - val_dsc: 0.9247 - val_accuracy: 0.9552 - val_IOU: 0.8873 - val_precision_m: 0.9431 - val_recall_m: 0.9244 - val_f1_m: 0.9336
# Epoch 81/100
# 87/87 [==============================] - 19s 217ms/step - loss: 0.0284 - dsc: 0.9464 - accuracy: 0.9617 - IOU: 0.9346 - precision_m: 0.9595 - recall_m: 0.9555 - f1_m: 0.9575 - val_loss: 0.0551 - val_dsc: 0.9223 - val_accuracy: 0.9547 - val_IOU: 0.8822 - val_precision_m: 0.9512 - val_recall_m: 0.9119 - val_f1_m: 0.9311
# Epoch 82/100
# 87/87 [==============================] - 20s 223ms/step - loss: 0.0280 - dsc: 0.9473 - accuracy: 0.9618 - IOU: 0.9359 - precision_m: 0.9603 - recall_m: 0.9560 - f1_m: 0.9581 - val_loss: 0.0526 - val_dsc: 0.9255 - val_accuracy: 0.9553 - val_IOU: 0.8886 - val_precision_m: 0.9468 - val_recall_m: 0.9225 - val_f1_m: 0.9345
# Epoch 83/100
# 87/87 [==============================] - 19s 220ms/step - loss: 0.0290 - dsc: 0.9457 - accuracy: 0.9615 - IOU: 0.9331 - precision_m: 0.9589 - recall_m: 0.9548 - f1_m: 0.9568 - val_loss: 0.0536 - val_dsc: 0.9244 - val_accuracy: 0.9551 - val_IOU: 0.8869 - val_precision_m: 0.9436 - val_recall_m: 0.9239 - val_f1_m: 0.9336
# Epoch 84/100
# 87/87 [==============================] - 20s 223ms/step - loss: 0.0283 - dsc: 0.9466 - accuracy: 0.9617 - IOU: 0.9350 - precision_m: 0.9596 - recall_m: 0.9556 - f1_m: 0.9576 - val_loss: 0.0522 - val_dsc: 0.9269 - val_accuracy: 0.9555 - val_IOU: 0.8912 - val_precision_m: 0.9364 - val_recall_m: 0.9351 - val_f1_m: 0.9357
# Epoch 85/100
# 87/87 [==============================] - 19s 219ms/step - loss: 0.0288 - dsc: 0.9462 - accuracy: 0.9615 - IOU: 0.9337 - precision_m: 0.9592 - recall_m: 0.9552 - f1_m: 0.9571 - val_loss: 0.0551 - val_dsc: 0.9247 - val_accuracy: 0.9546 - val_IOU: 0.8866 - val_precision_m: 0.9274 - val_recall_m: 0.9393 - val_f1_m: 0.9333
# Epoch 86/100
# 87/87 [==============================] - 20s 224ms/step - loss: 0.0285 - dsc: 0.9463 - accuracy: 0.9617 - IOU: 0.9345 - precision_m: 0.9594 - recall_m: 0.9554 - f1_m: 0.9573 - val_loss: 0.0530 - val_dsc: 0.9251 - val_accuracy: 0.9552 - val_IOU: 0.8875 - val_precision_m: 0.9470 - val_recall_m: 0.9213 - val_f1_m: 0.9340
# Epoch 87/100
# 87/87 [==============================] - 19s 217ms/step - loss: 0.0286 - dsc: 0.9463 - accuracy: 0.9616 - IOU: 0.9340 - precision_m: 0.9594 - recall_m: 0.9552 - f1_m: 0.9572 - val_loss: 0.0517 - val_dsc: 0.9269 - val_accuracy: 0.9556 - val_IOU: 0.8908 - val_precision_m: 0.9433 - val_recall_m: 0.9282 - val_f1_m: 0.9357
# Epoch 88/100
# 87/87 [==============================] - 19s 220ms/step - loss: 0.0283 - dsc: 0.9468 - accuracy: 0.9617 - IOU: 0.9351 - precision_m: 0.9597 - recall_m: 0.9559 - f1_m: 0.9577 - val_loss: 0.0525 - val_dsc: 0.9268 - val_accuracy: 0.9555 - val_IOU: 0.8905 - val_precision_m: 0.9417 - val_recall_m: 0.9294 - val_f1_m: 0.9355
# Epoch 89/100
# 87/87 [==============================] - 19s 218ms/step - loss: 0.0284 - dsc: 0.9468 - accuracy: 0.9617 - IOU: 0.9349 - precision_m: 0.9599 - recall_m: 0.9556 - f1_m: 0.9577 - val_loss: 0.0536 - val_dsc: 0.9231 - val_accuracy: 0.9550 - val_IOU: 0.8846 - val_precision_m: 0.9488 - val_recall_m: 0.9162 - val_f1_m: 0.9322
# Epoch 90/100
# 87/87 [==============================] - 20s 223ms/step - loss: 0.0282 - dsc: 0.9469 - accuracy: 0.9617 - IOU: 0.9353 - precision_m: 0.9598 - recall_m: 0.9559 - f1_m: 0.9578 - val_loss: 0.0594 - val_dsc: 0.9203 - val_accuracy: 0.9539 - val_IOU: 0.8785 - val_precision_m: 0.9407 - val_recall_m: 0.9177 - val_f1_m: 0.9290
# Epoch 91/100
# 87/87 [==============================] - 20s 223ms/step - loss: 0.0274 - dsc: 0.9481 - accuracy: 0.9620 - IOU: 0.9375 - precision_m: 0.9607 - recall_m: 0.9570 - f1_m: 0.9588 - val_loss: 0.0531 - val_dsc: 0.9248 - val_accuracy: 0.9552 - val_IOU: 0.8868 - val_precision_m: 0.9516 - val_recall_m: 0.9163 - val_f1_m: 0.9336
# Epoch 92/100
# 87/87 [==============================] - 19s 218ms/step - loss: 0.0277 - dsc: 0.9479 - accuracy: 0.9619 - IOU: 0.9366 - precision_m: 0.9605 - recall_m: 0.9566 - f1_m: 0.9585 - val_loss: 0.0541 - val_dsc: 0.9254 - val_accuracy: 0.9551 - val_IOU: 0.8869 - val_precision_m: 0.9480 - val_recall_m: 0.9198 - val_f1_m: 0.9337
# Epoch 93/100
# 87/87 [==============================] - 20s 225ms/step - loss: 0.0283 - dsc: 0.9469 - accuracy: 0.9617 - IOU: 0.9349 - precision_m: 0.9596 - recall_m: 0.9558 - f1_m: 0.9577 - val_loss: 0.0608 - val_dsc: 0.9204 - val_accuracy: 0.9535 - val_IOU: 0.8783 - val_precision_m: 0.9276 - val_recall_m: 0.9307 - val_f1_m: 0.9291
# Epoch 94/100
# 87/87 [==============================] - 19s 218ms/step - loss: 0.0282 - dsc: 0.9471 - accuracy: 0.9617 - IOU: 0.9354 - precision_m: 0.9599 - recall_m: 0.9559 - f1_m: 0.9579 - val_loss: 0.0544 - val_dsc: 0.9254 - val_accuracy: 0.9551 - val_IOU: 0.8881 - val_precision_m: 0.9326 - val_recall_m: 0.9357 - val_f1_m: 0.9341
# Epoch 95/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0278 - dsc: 0.9477 - accuracy: 0.9619 - IOU: 0.9365 - precision_m: 0.9605 - recall_m: 0.9563 - f1_m: 0.9584 - val_loss: 0.0540 - val_dsc: 0.9269 - val_accuracy: 0.9552 - val_IOU: 0.8904 - val_precision_m: 0.9307 - val_recall_m: 0.9402 - val_f1_m: 0.9354
# Epoch 96/100
# 87/87 [==============================] - 20s 224ms/step - loss: 0.0273 - dsc: 0.9486 - accuracy: 0.9620 - IOU: 0.9377 - precision_m: 0.9608 - recall_m: 0.9573 - f1_m: 0.9590 - val_loss: 0.0522 - val_dsc: 0.9273 - val_accuracy: 0.9555 - val_IOU: 0.8914 - val_precision_m: 0.9385 - val_recall_m: 0.9333 - val_f1_m: 0.9359
# Epoch 97/100
# 87/87 [==============================] - 19s 221ms/step - loss: 0.0282 - dsc: 0.9473 - accuracy: 0.9617 - IOU: 0.9353 - precision_m: 0.9599 - recall_m: 0.9559 - f1_m: 0.9579 - val_loss: 0.0553 - val_dsc: 0.9237 - val_accuracy: 0.9543 - val_IOU: 0.8857 - val_precision_m: 0.9232 - val_recall_m: 0.9424 - val_f1_m: 0.9327
# Epoch 98/100
# 87/87 [==============================] - 19s 219ms/step - loss: 0.0276 - dsc: 0.9478 - accuracy: 0.9619 - IOU: 0.9368 - precision_m: 0.9605 - recall_m: 0.9567 - f1_m: 0.9586 - val_loss: 0.0542 - val_dsc: 0.9270 - val_accuracy: 0.9554 - val_IOU: 0.8898 - val_precision_m: 0.9419 - val_recall_m: 0.9287 - val_f1_m: 0.9352
# Epoch 99/100
# 87/87 [==============================] - 19s 218ms/step - loss: 0.0272 - dsc: 0.9488 - accuracy: 0.9620 - IOU: 0.9381 - precision_m: 0.9612 - recall_m: 0.9574 - f1_m: 0.9593 - val_loss: 0.0564 - val_dsc: 0.9259 - val_accuracy: 0.9546 - val_IOU: 0.8877 - val_precision_m: 0.9222 - val_recall_m: 0.9461 - val_f1_m: 0.9339
# Epoch 100/100
# 87/87 [==============================] - 19s 223ms/step - loss: 0.0265 - dsc: 0.9498 - accuracy: 0.9623 - IOU: 0.9400 - precision_m: 0.9619 - recall_m: 0.9584 - f1_m: 0.9601 - val_loss: 0.0533 - val_dsc: 0.9282 - val_accuracy: 0.9555 - val_IOU: 0.8920 - val_precision_m: 0.9331 - val_recall_m: 0.9396 - val_f1_m: 0.9363

# %%
train_loss = history.history['loss']
valid_loss = history.history['val_loss']

train_acc = history.history['accuracy']
valid_acc = history.history['val_accuracy']

# %%
from numpy import savetxt
savetxt('train_loss_LLD.csv', train_loss, delimiter=',')
savetxt('valid_loss_LLD.csv', valid_loss, delimiter=',')

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(13,4))
axes = axes.flatten()

axes[0].plot(train_acc, label='training')
axes[0].plot(valid_acc, label='validation')
axes[0].set_title('Accuracy Curve')
axes[0].set_xlabel('epochs')
axes[0].set_ylabel('accuracy')
axes[0].legend()


axes[1].plot(train_loss, label='training')
axes[1].plot(valid_loss, label='validation')
axes[1].set_title('Loss Curve')
axes[1].set_xlabel('epochs')
axes[1].set_ylabel('loss')
axes[1].legend()

plt.show()

# %%
train_dice = history.history['dsc']
valid_dice = history.history['val_dsc']


train_IOU = history.history['IOU']
valid_IOU = history.history['val_IOU']
#history.history

# %%
from numpy import savetxt
savetxt('train_dice_LLD.csv', train_dice, delimiter=',')
savetxt('valid_dice_LLD.csv', valid_dice, delimiter=',')

savetxt('train_IOU_LLD.csv', train_IOU, delimiter=',')
savetxt('valid_IOU_LLD.csv', valid_IOU, delimiter=',')

# %%
fig, axes = plt.subplots(1, 2, figsize=(20,7))
axes = axes.flatten()

axes[0].plot(train_IOU, label='training')
axes[0].plot(valid_IOU, label='validation')
axes[0].set_title('IOU Curve ')
axes[0].set_xlabel('epochs')
axes[0].set_ylabel('IOU')
axes[0].legend()


axes[1].plot(train_dice, label='training')
axes[1].plot(valid_dice, label='validation')
axes[1].set_title('Dice coefficient Curve')
axes[1].set_xlabel('epochs')
axes[1].set_ylabel('dice_coef')
axes[1].legend()

plt.show()

# %%
model.save('LLDNet_new.h5')

# %%
y_pred = model.predict(X_val)
# Out:
# 75/75 [==============================] - 3s 27ms/step

# %%
IOU(y_pred, y_val)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.8918724>
